# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import urllib
import urllib.request
import time
import sys
import os
import random
import math
import pandas as pd

site= "https://a253013.sitemaphosting6.com/4227023/sitemap.xml"

driver = webdriver.Firefox()
driver.get(site)
soup = BeautifulSoup(driver.page_source, 'html.parser')
div_tags = soup.find_all("div")
div=div_tags[1]
links=div.findAll("a")
urls=[]
for i in range(len(links)):
    a=str(links[i])
    i=a.find("https")
    j=a.rfind("https")
    b=a[i:j-2]
    urls.append(b)


ll=[]
for i in range(len(urls)):
    if urls[i].find("encyc")!=-1 or urls[i].find("Encyc")!=-1 or urls[i].find("archives")!=-1:
        
        ll.append(urls[i])
    
    else:
        pass

ll=ll[1:]
clean=[]
for i in range(len(ll)):
    if ll[i].find("archives")!=-1:
        if ll[i].find("page=") !=-1:
            clean.append(ll[i])
        else:
            pass
    else:
        clean.append(ll[i])

clean1=[]
for i in clean:
    if i.find("pdf")==-1:
        clean1.append(i)
    else:
        pass
    
sites=[]
dates=[]
titles=[]
for i in range(len(clean1)):
    if clean1[i].find("encyc")!=-1 or clean1[i].find("Encyc")!=-1:
        #date
        url=clean1[i]
        s=clean1[i].find('Encyc')
        if s==-1:
            t=clean1[i].find('encyc')
            a=t+6
        else:
            a=s+6
            
        b=clean1[i].rfind('/')
        #title
        c=url.rfind('/')+1
        d=url[c:]
        title=d[0:-5]
        date=url[a:b]
        
        sites.append(url)
        dates.append(date)
        titles.append(title)
        
gdates=[]
for i in range(len(dates)):
    gdates.append(dates[i]+'g')

years=[]
months=[]
days=[]
for i in range(len(dates)):
    years.append(dates[i][0:4])
    a=dates[i].find("/")
    b=dates[i].rfind("/")
    months.append(dates[i][a+1:b])
    e=gdates[i].rfind("/")
    f=gdates[i].rfind("g")
    days.append(gdates[i][e+1:f])

doubles=['10','11','12']
m=[]
for i in range(len(months)):
    if months[i] in doubles:
        m.append(months[i])
    else:
        m.append('0'+months[i])
singles=['1','2','3','4','5','6','7','8','9']
d=[]
for i in range(len(days)):
    if days[i] in singles :
        d.append('0'+days[i])
        
    else:
        d.append(days[i])
code=[]
for i in range(len(years)):
    digits = [i for i in range(0, 10)]
    random_str = ""
    for i in range(6):
        index = math.floor(random.random() * 10)
        random_str += str(digits[index])
    code.append(random_str)


"""dframe=pd.DataFrame(columns=["sites","dates","titles"])
dframe["sites"]=sites
dframe["dates"]=dates
dframe["titles"]=titles"""

for i in range(len(sites)):
    with open('t{}{}{}{}.txt'.format(years[i],m[i],d[i],code[i]),'w') as f:
    

        url=sites[i]
        driver = webdriver.Firefox()
        driver.get(url)
        obj = BeautifulSoup(driver.page_source, 'html.parser')
        driver.close()
        cp=obj.find('div', attrs={'class':'body_container'})
        cp=str(cp)
        
        #paras=[]
        #paras=obj.findAll("div", id="pastingspan1")
            
        #paras=paras[2:]
        #cp=""
        #for j in range(len(paras)):
            #a=str(paras[j]).strip('<div id="pastingspan1">')
            #b=a.strip('</')
            #cp=cp+b 
        
        #if cp == "":
            #nothing=nothing+1
            #nf.append(titles[i])
            
        s=0
        while s!=-1:
            s=cp.find("<")
            e=cp.find(">")
            cp=cp.replace(cp[s:e+1],"")
        
        
        f.write(dates[i])
        f.write('\n')
        f.write('\n')
        f.write(titles[i])
        f.write('\n')
        f.write('\n')
        f.write(cp)
        f.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-f3cc47acf3f9> in <module>
#     132         url=sites[i]
#     133         driver = webdriver.Firefox()
# --> 134         driver.get(url)
#     135         obj = BeautifulSoup(driver.page_source, 'html.parser')
#     136         driver.close()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# ...

# %%
sites
# Out:
# ['https://www.organiser.org/Encyc/2021/5/19/India-Israel-bond-and-cooperation-to-fight-global-terror.html',
#  'https://www.organiser.org/Encyc/2021/5/18/Israeli-forces-strike-9-rocket-launch-sites-throughout-Gaza.html',
#  'https://www.organiser.org/Encyc/2021/5/18/Kerala-Central-University-suspends-assistant-professor-for-giving-a-call-for-militant-rebellion-agai.html',
#  'https://www.organiser.org/Encyc/2021/5/18/MRM-to-launch-positivity-drive-to-defeat-Chinese-bio-weapon-Covid-19-attack.html',
#  'https://www.organiser.org/Encyc/2021/5/18/The-RSS-Way-Sewa-During-the-Troubled-Times-of-Pandemic.html',
#  'https://www.organiser.org/Encyc/2021/5/18/-Don-t-Comment-on-Eid-Call-Super-Spreader-Kumbh-.html',
#  'https://www.organiser.org/Encyc/2021/5/18/West-Bengal-Narada-scam-Arrested-TMC-leaders-taken-to-Presidency-jail.html',
#  'https://www.organiser.org/Encyc/2021/5/18/West-Bengal-Assembly-Election-2021-Did-the-LEFT-Bled-BJP-Through-Thousand-Cuts-.html',
# ...

# %%
dates[1000]
# Out:
# '2020/7/4'

# %%
titles
# Out:
# ['India-Israel-bond-and-cooperation-to-fight-global-terror',
#  'Israeli-forces-strike-9-rocket-launch-sites-throughout-Gaza',
#  'Kerala-Central-University-suspends-assistant-professor-for-giving-a-call-for-militant-rebellion-agai',
#  'MRM-to-launch-positivity-drive-to-defeat-Chinese-bio-weapon-Covid-19-attack',
#  'The-RSS-Way-Sewa-During-the-Troubled-Times-of-Pandemic',
#  '-Don-t-Comment-on-Eid-Call-Super-Spreader-Kumbh-',
#  'West-Bengal-Narada-scam-Arrested-TMC-leaders-taken-to-Presidency-jail',
#  'West-Bengal-Assembly-Election-2021-Did-the-LEFT-Bled-BJP-Through-Thousand-Cuts-',
#  'Hindus-and-Jews-The-history-of-the-mutual-interaction-and-relation-between-the-two-oldest-civilizat',
#  'Ram-Mandir-Nirmaan-Katha-Nidhi-Samarpan-and-Asha-Kanwar-s-last-wish',
#  'Ram-Mandir-Nidhi-Samarpan-Kadha-12-year-old-Madhav-donates-money-saved-to-purchase-cricket-bat-to-the-toli',
#  'Ram-Mandir-Nirmaan-Katha-a-rupee-10-note-and-devotion-to-Lord-Ram',
#  'They-Want-India-to-Fail-',
# ...

# %%
dates
# Out:
# ['2021/5/19',
#  '2021/5/18',
#  '2021/5/18',
#  '2021/5/18',
#  '2021/5/18',
#  '2021/5/18',
#  '2021/5/18',
#  '2021/5/18',
#  '2021/5/17',
#  '2021/2/17',
#  '2021/2/15',
#  '2021/2/13',
#  '2021/5/18',
#  '2021/5/18',
#  '2021/5/18',
#  '2021/5/18',
#  '2021/5/18',
#  '2021/5/17',
#  '2021/5/16',
#  '2021/5/14',
#  '2021/4/12',
#  '2021/5/15',
#  '2021/5/13',
#  '2021/5/11',
#  '2021/5/11',
#  '2021/5/11',
#  '2021/5/10',
#  '2021/5/9',
#  '2021/5/9',
#  '2021/3/9',
#  '2021/1/15',
#  '2020/11/20',
#  '2020/11/18',
#  '2020/10/31',
#  '2020/9/10',
#  '2020/9/6',
#  '2020/8/20',
#  '2020/7/2',
#  '2020/6/6',
#  '2020/5/29',
#  '2020/5/22',
#  '2020/5/21',
#  '2020/5/21',
#  '2021/4/26',
#  '2021/5/14',
#  '2021/4/15',
#  '2021/1/25',
#  '2021/3/17',
#  '2021/2/17',
#  '2021/1/28',
#  '2021/5/18',
#  '2021/5/15',
#  '2021/5/15',
#  '2021/5/15',
#  '2021/5/16',
#  '2021/5/14',
#  '2021/5/14',
#  '2021/5/12',
#  '2019/8/23',
#  '2019/2/12',
#  '2019/11/21',
#  '2019/8/23',
# ...

# %%
days
# Out:
# ['19',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '17',
#  '17',
#  '15',
#  '13',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '17',
#  '16',
#  '14',
#  '12',
#  '15',
#  '13',
#  '11',
#  '11',
#  '11',
#  '10',
#  '9',
#  '9',
#  '9',
#  '15',
#  '20',
#  '18',
#  '31',
#  '10',
#  '6',
#  '20',
#  '2',
#  '6',
#  '29',
#  '22',
#  '21',
#  '21',
#  '26',
#  '14',
#  '15',
#  '25',
#  '17',
#  '17',
#  '28',
#  '18',
#  '15',
#  '15',
#  '15',
#  '16',
#  '14',
#  '14',
#  '12',
#  '23',
#  '12',
#  '21',
#  '23',
#  '23',
#  '18',
#  '18',
#  '18',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '16',
#  '16',
#  '16',
#  '16',
#  '16',
#  '15',
#  '15',
#  '15',
#  '15',
#  '15',
#  '15',
#  '15',
#  '15',
#  '15',
#  '14',
#  '14',
#  '14',
#  '14',
#  '14',
#  '14',
#  '14',
#  '14',
#  '14',
#  '14',
#  '14',
#  '13',
#  '13',
#  '13',
#  '13',
#  '13',
#  '13',
#  '13',
# ...

# %%
sites[1001]
# Out:
# 'https://www.organiser.org/Encyc/2020/7/2/Dr-RaghunathMashelkar.html'

# %%
dates[1001]
# Out:
# '2020/7/2'

# %%
titles[1001]
# Out:
# 'Dr-RaghunathMashelkar'

# %%
days[1001]
# Out:
# '2'

# %%
months[1001]
# Out:
# '7'

# %%
years[1001]
# Out:
# '2020'

# %%
sites[1]
# Out:
# 'https://www.organiser.org/Encyc/2021/5/18/Israeli-forces-strike-9-rocket-launch-sites-throughout-Gaza.html'

# %%
matter[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1e61d3559a83> in <module>
# ----> 1 matter[1]
#
# NameError: name 'matter' is not defined

# %%
sites[0]
# Out:
# 'https://www.organiser.org/Encyc/2021/5/19/India-Israel-bond-and-cooperation-to-fight-global-terror.html'

# %%
titles[0]
# Out:
# 'India-Israel-bond-and-cooperation-to-fight-global-terror'

# %%
days[0]
# Out:
# '19'

# %%
len(sites)
# Out:
# 6197

# %%
len(titles)
# Out:
# 6197

# %%
sites[1056]
# Out:
# 'https://www.organiser.org/Encyc/2019/1/20/PM-inaugurates-National-Museum-of-Indian-Cinema.html'

# %%
titles[1056]
# Out:
# 'PM-inaugurates-National-Museum-of-Indian-Cinema'

# %%
for i in range(len(sites)):
    print(titles[i])
   
    print(sites[i])
    print("******")
# Out:
# India-Israel-bond-and-cooperation-to-fight-global-terror
# https://www.organiser.org/Encyc/2021/5/19/India-Israel-bond-and-cooperation-to-fight-global-terror.html
# ******
# Israeli-forces-strike-9-rocket-launch-sites-throughout-Gaza
# https://www.organiser.org/Encyc/2021/5/18/Israeli-forces-strike-9-rocket-launch-sites-throughout-Gaza.html
# ******
# Kerala-Central-University-suspends-assistant-professor-for-giving-a-call-for-militant-rebellion-agai
# https://www.organiser.org/Encyc/2021/5/18/Kerala-Central-University-suspends-assistant-professor-for-giving-a-call-for-militant-rebellion-agai.html
# ******
# MRM-to-launch-positivity-drive-to-defeat-Chinese-bio-weapon-Covid-19-attack
# https://www.organiser.org/Encyc/2021/5/18/MRM-to-launch-positivity-drive-to-defeat-Chinese-bio-weapon-Covid-19-attack.html
# ******
# The-RSS-Way-Sewa-During-the-Troubled-Times-of-Pandemic
# https://www.organiser.org/Encyc/2021/5/18/The-RSS-Way-Sewa-During-the-Troubled-Times-of-Pandemic.html
# ******
# ...

# %%
len(days)
# Out:
# 6197

# %%
len(titles)
# Out:
# 6197

# %%
len(sites)
# Out:
# 6197

# %%
len(dates)
# Out:
# 6197

# %%
sites1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-444f31a5245d> in <module>
# ----> 1 sites1
#
# NameError: name 'sites1' is not defined

# %%
len(clean1)
# Out:
# 20819

# %%
len(clean)
# Out:
# 20841

# %%
titles[4]
# Out:
# 'The-RSS-Way-Sewa-During-the-Troubled-Times-of-Pandemic'

# %%
sites[4]
# Out:
# 'https://www.organiser.org/Encyc/2021/5/18/The-RSS-Way-Sewa-During-the-Troubled-Times-of-Pandemic.html'

# %%
paras==-1
# Out:
# False

# %%
nothing
# Out:
# 0

# %%
nothing
# Out:
# 0

# %%
nf
# Out:
# []

# %%
url = "https://www.organiser.org/Encyc/2021/5/18/They-Want-India-to-Fail-.html"

# %%
nothing=0
nf=[]
driver = webdriver.Firefox()
driver.get(url)
obj = BeautifulSoup(driver.page_source, 'html.parser')

p=obj.find('div', attrs={'class':'body_container'})
       
print(p)
# Out:
# <div class="body_container">
# ...

# %%
p=str(p)

# %%
type(p)
# Out:
# str

# %%
p
# Out:
# '<div class="body_container">\n<div style="text-align: center; "></div><div style="text-align: center; ">\xa0<br/><img alt="a_1\xa0\xa0H x W: 0 x" src="https://www.organiser.org/Encyc/2021/5/18/2_04_52_28_a_1_H@@IGHT_415_W@@IDTH_650.jpg" title="a_1\xa0\xa0H x W: 0 x"/></div><div>\xa0</div><div>\xa0</div><div><div id="pastingspan1">Modi detractors presume that the Government has been cornered by the second wave of the COVID crisis. There is a sadistic pleasure at the plight of people. The human tragedy, a huge number of deaths and fresh challenges to the national economy do not bother them.</div><div id="pastingspan1">\xa0</div><div>They are more inclined to see the Prime Minister in the dock. Hence, there is an attempt to discredit the entire \'Vaccine Maitri\' (or Vaccine Diplomacy). The power of \'anti-Modi\' rhetoric as the garb of objectivity is so intense that it is difficult to express an opinion and that would still be considered an objective one. If one writes with a few laud
# ...

# %%
cp
# Out:
# '\xa0\xa0\xa0\xa0\xa0\xa0'

# %%
nothing
# Out:
# 0

# %%
paras
# Out:
# [<div id="pastingspan1" style="text-align: center; "> <br/><img alt="1_1  H x W: 0 x" src="https://www.organiser.org/Encyc/2020/10/31/2_08_16_15_1_1_H@@IGHT_450_W@@IDTH_680.jpg" title="1_1  H x W: 0 x"/></div>]

# %%
with open("yashu.txt",'w') as f:
    print(5)
# Out:
# 5

# %%
with open('t{}{}{}{}.txt'.format(years[i],m[i],d[i],code[i]),'w') as f:
            
            paras=paras[2:]
            cp=""
            for j in range(len(paras)):
                a=str(paras[j]).strip('<div id="pastingspan1">')
                b=a.strip('</')
                cp=cp+b

# %%
cp
# Out:
# ''

# %%
cp==""
# Out:
# True

# %%
nothing
# Out:
# 1

# %%
nf
# Out:
# ['India-Israel-bond-and-cooperation-to-fight-global-terror']
